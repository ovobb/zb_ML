# %%
import pandas as pd

red_url = "https://raw.githubusercontent.com/PinkWink/ML_tutorial/master/dataset/winequality-red.csv"
white_url = "https://raw.githubusercontent.com/PinkWink/ML_tutorial/master/dataset/winequality-white.csv"

red_wine = pd.read_csv(red_url, sep=';')
white_wine = pd.read_csv(white_url, sep=';')

red_wine['color'] = 1.
white_wine['color'] = 0.

wine = pd.concat([red_wine, white_wine])

X = wine.drop(['color'], axis=1)
y = wine['color']

# %% [markdown]
# ### pipeline을 이용하면 간결하게 나타낼 수 있음

# %%
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler

estimators = [
    ('scalar', StandardScaler()),          # 첫번째 단계는 이거
    ('clf', DecisionTreeClassifier())      # 두번째 단계는 이거
]

pipe = Pipeline(estimators)

# %%
pipe
# Out:
# Pipeline(steps=[('scalar', StandardScaler()),
#                 ('clf', DecisionTreeClassifier())])

# %%
pipe.steps
# Out:
# [('scalar', StandardScaler()), ('clf', DecisionTreeClassifier())]

# %%
pipe.steps[0], pipe.steps[1]
# Out:
# (('scalar', StandardScaler()), ('clf', DecisionTreeClassifier()))

# %%
# 언더바(_) 두개는 바로 속성으로 지정해준다는 뜻.
# 아래 코드 해석해보면 clf의 max_depth라는 속성을 2로 지정해주라는 뜻

pipe.set_params(clf__max_depth=2)
pipe.set_params(clf__random_state=13)
# Out:
# Pipeline(steps=[('scalar', StandardScaler()),
#                 ('clf', DecisionTreeClassifier(max_depth=2, random_state=13))])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13, stratify=y)

# %%
X_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3437            6.7              0.40         0.22             8.8      0.052
# 2124            7.7              0.39         0.28             4.9      0.035
# 3005            6.9              0.30         0.36             0.9      0.037
# 2436            6.9              0.43         0.28             9.4      0.056
# 444             6.9              0.24         0.36            20.8      0.031
# ...             ...               ...          ...             ...        ...
# 4710            5.4              0.33         0.31             4.0      0.030
# 44              6.7              0.23         0.26             1.4      0.060
# 1987            8.1              0.22         0.28             7.7      0.043
# 2422            6.2              0.44         0.18             7.7      0.096
# 1169            7.5              0.14         0.34             1.3      0.055
#
# ...

# %%
pipe.fit(X_train, y_train)  # 자기가 알아서 스케일러를 통과시키고 학습시킴
# Out:
# Pipeline(steps=[('scalar', StandardScaler()),
#                 ('clf', DecisionTreeClassifier(max_depth=2, random_state=13))])

# %%
from sklearn.metrics import accuracy_score

y_pred_tr = pipe.predict(X_train)
y_pred_test = pipe.predict(X_test)

print('Train acc :', accuracy_score(y_train, y_pred_tr))
print('Test acc :', accuracy_score(y_test, y_pred_test))
# Out:
# Train acc : 0.9657494708485664
# Test acc : 0.9576923076923077

# %%
import matplotlib.pyplot as plt
import sklearn.tree as tree

plt.figure(figsize=(12,8))
tree.plot_tree(pipe['clf'], feature_names=X.columns,
               rounded=True,
               filled=True)
plt.show()
